# %%
import os
import pandas as pd
import seaborn as sns
import numpy as np

# %% [markdown]
# # 그래프 한글꺠짐 처리 (윈도우)

# %%
import matplotlib
import platform
from matplotlib import font_manager, rc

font_name = font_manager.FontProperties(fname="c:/Windows/Fonts/malgun.ttf").get_name()
rc('font', family=font_name)

matplotlib.rcParams['axes.unicode_minus'] = False   
#그래프에서 마이너스 기호가 표시되도록 하는 설정입니다.

# %%
# 모든 컬럼이 표시되도록 max_columns 의 수를 지정합니다.
pd.options.display.max_columns = 10000
pd.set_option('display.max_rows', 2000)

# %%
path = 'dataset/오이/'
df = pd.read_excel(path + '경상북도_정--농가데이터셋_오이.xlsx')

# %%
df
# Out:
#                시설ID    농가명    시도  시군구 품목명    품종  재배면적 시설유형 재배형태 단동/연동 구분  \
# 0     PF_0001665_01  정****  경상북도  상주시  오이  백다다기  5200   비닐   수경       연동
# 1     PF_0001665_01  정****  경상북도  상주시  오이  백다다기  5200   비닐   수경       연동
# 2     PF_0001665_01  정****  경상북도  상주시  오이  백다다기  5200   비닐   수경       연동
# 3     PF_0001665_01  정****  경상북도  상주시  오이  백다다기  5200   비닐   수경       연동
# 4     PF_0001665_01  정****  경상북도  상주시  오이  백다다기  5200   비닐   수경       연동
# ...             ...    ...   ...  ...  ..   ...   ...  ...  ...      ...
# 5250  PF_0001665_01  정****  경상북도  상주시  오이  백다다기  5200   비닐   수경       연동
# 5251  PF_0001665_01  정****  경상북도  상주시  오이  백다다기  5200   비닐   수경       연동
# 5252  PF_0001665_01  정****  경상북도  상주시  오이  백다다기  5200   비닐   수경       연동
# 5253  PF_0001665_01  정****  경상북도  상주시  오이  백다다기  5200   비닐   수경       연동
# 5254  PF_0001665_01  정****  경상북도  상주시  오이  백다다기  5200   비닐   수경       연동
#
#                       수집일   외부온도   외부습도  외부 일사량  외부풍향  외부풍속  외부강우  강우감지  \
# ...

# %%
df.shape
# Out:
# (5255, 84)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5255 entries, 0 to 5254
# Data columns (total 84 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   시설ID         5255 non-null   object
#  1   농가명          5255 non-null   object
#  2   시도           5255 non-null   object
#  3   시군구          5255 non-null   object
#  4   품목명          5255 non-null   object
#  5   품종           5255 non-null   object
#  6   재배면적         5255 non-null   int64
#  7   시설유형         5255 non-null   object
#  8   재배형태         5255 non-null   object
#  9   단동/연동 구분     5255 non-null   object
#  10  수집일          5255 non-null   object
#  11  외부온도         5168 non-null   float64
#  12  외부습도         5178 non-null   float64
#  13  외부 일사량       0 non-null      float64
#  14  외부풍향         5237 non-null   float64
#  15  외부풍속         4605 non-null   float64
#  16  외부강우         0 non-null      float64
#  17  강우감지         5237 non-null   float64
# ...

# %%
df.columns
# Out:
# Index(['시설ID', '농가명', '시도', '시군구', '품목명', '품종', '재배면적', '시설유형', '재배형태',
#        '단동/연동 구분', '수집일', '외부온도', '외부습도', '외부 일사량', '외부풍향', '외부풍속', '외부강우',
#        '강우감지', '내부온도', '내부습도', '내부CO2', '내부 일사량', '토양EC', '토양PH', '지온', '지습',
#        '(양액)총배액', '(양액)총급액', '(양액)배액PH', '(양액)공급PH', '(양액)배액EC', '(양액)공급EC',
#        '(양액)지온', '(양액)지습', '배기팬작동여부', 'CO2발생장치작동여부', '보광등작동여부', '난방기작동상태',
#        '난방기작동여부', '유동팬작동상태', '유동팬작동여부', '보온커튼작동상태', '보온커튼작동여부', '차광커튼작동상태',
#        '차광커튼작동여부', '우측삼중측창 작동여부', '좌측삼중측창 작동여부', '우측이중측창 작동여부', '좌측이중측창 작동여부',
#        '우측일중측창 개도', '우측일중측창 온도폭', '우측일중측창 설정온도', '우측일중측창 작동여부', '우측일중측창 작동상태',
#        '좌측일중측창 개도', '좌측일중측창 온도폭', '좌측일중측창 설정온도', '좌측일중측창 작동여부', '좌측일중측창 작동상태',
#        '측창', '우측이중천창 작동여부', '좌측이중천창 작동여부', '우측일중천창 개도', '우측일중천창 온도폭',
#        '우측일중천창 설정온도', '우측일중천창 작동여부', '우측일중천창 작동상태', '좌측일중천창 개도', '좌측일중천창 온도폭',
#        '좌측일중천창 설정온도', '좌측일중천창 작동여부', '좌측일중천창 작동상태', '천창', '조사일', '주차', '초장',
# ...

# %% [markdown]
# # null 값 밖에 없는 칼럼 날리기

# %% [markdown]
# null 값 밖에 없음
#
# * '외부 일사량', '외부강우', "내부 일사량", "외부 강우", "지온", "지습", "보광등작동여부", "난방기작동상태", "유동팬작동상태", "보온커튼작동상태", "차광커튼작동상태", "우측일중측창 개도", "우측일중측창 온도폭", "우측일중측창 설정온도", "우측일중측창 작동상태", "좌측일중측창 개도", "좌측일중측창 온도폭", "좌측일중측창 설정온도", "측일중측창 작동상태", "측창", "우측일중천창 개도", "우측일중천창 온도폭", "우측일중천창 설정온도", "우측일중천창 작동상태", "좌측일중천창 개도", "좌측일중천창 온도폭", "좌측일중천창 설정온도", "좌측일중천창 작동상태", "천창"

# %%
df = df.drop(['외부 일사량',"외부강우", "내부 일사량", "지온", "지습", "보광등작동여부", "난방기작동상태", "유동팬작동상태", "보온커튼작동상태", "차광커튼작동상태", "우측일중측창 개도", "우측일중측창 온도폭", "우측일중측창 설정온도", "우측일중측창 작동상태", "좌측일중측창 개도", "좌측일중측창 온도폭", "좌측일중측창 설정온도", "좌측일중측창 작동상태", "측창", "우측일중천창 개도", "우측일중천창 온도폭", "우측일중천창 설정온도", "우측일중천창 작동상태", "좌측일중천창 개도", "좌측일중천창 온도폭", "좌측일중천창 설정온도", "좌측일중천창 작동상태", "천창"],axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5255 entries, 0 to 5254
# Data columns (total 56 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   시설ID         5255 non-null   object
#  1   농가명          5255 non-null   object
#  2   시도           5255 non-null   object
#  3   시군구          5255 non-null   object
#  4   품목명          5255 non-null   object
#  5   품종           5255 non-null   object
#  6   재배면적         5255 non-null   int64
#  7   시설유형         5255 non-null   object
#  8   재배형태         5255 non-null   object
#  9   단동/연동 구분     5255 non-null   object
#  10  수집일          5255 non-null   object
#  11  외부온도         5168 non-null   float64
#  12  외부습도         5178 non-null   float64
#  13  외부풍향         5237 non-null   float64
#  14  외부풍속         4605 non-null   float64
#  15  강우감지         5237 non-null   float64
#  16  내부온도         5237 non-null   float64
#  17  내부습도         5099 non-null   float64
# ...

# %%
df.corr()['열매수']#[abs(df.corr()['열매수']) > 0.0 ]
# Out:
# 재배면적                NaN
# 외부온도           0.640714
# 외부습도           0.366435
# 외부풍향          -0.239786
# 외부풍속          -0.522460
# 강우감지           0.307204
# 내부온도          -0.028305
# 내부습도          -0.708042
# 내부CO2         -0.633844
# 토양EC                NaN
# 토양PH                NaN
# (양액)총배액             NaN
# (양액)총급액             NaN
# (양액)배액PH            NaN
# (양액)공급PH            NaN
# (양액)배액EC            NaN
# (양액)공급EC            NaN
# (양액)지온        -0.483720
# (양액)지습        -0.655778
# 배기팬작동여부        0.332970
# CO2발생장치작동여부         NaN
# 난방기작동여부             NaN
# 유동팬작동여부             NaN
# 보온커튼작동여부       0.332970
# 차광커튼작동여부       0.332970
# 우측삼중측창 작동여부    0.581400
# 좌측삼중측창 작동여부    0.581401
# 우측이중측창 작동여부    0.751165
# 좌측이중측창 작동여부    0.751165
# 우측일중측창 작동여부    0.095005
# 좌측일중측창 작동여부    0.746271
# 우측이중천창 작동여부    0.627957
# 좌측이중천창 작동여부    0.627927
# 우측일중천창 작동여부    0.373043
# 좌측일중천창 작동여부    0.348700
# 초장            -0.239648
# 마디수            0.958041
# 엽장             0.974611
# ...

# %% [markdown]
# # 그 외 필요없는 값 날리기

# %%
df = df.drop(['(양액)총배액', '(양액)총급액', '(양액)공급PH', '(양액)공급EC', '(양액)지온', '(양액)지습','배기팬작동여부','CO2발생장치작동여부','난방기작동여부','유동팬작동여부','보온커튼작동여부','차광커튼작동여부','우측삼중측창 작동여부','좌측삼중측창 작동여부','우측이중측창 작동여부','좌측이중측창 작동여부','우측일중측창 작동여부','좌측일중측창 작동여부','우측이중천창 작동여부','좌측이중천창 작동여부','우측일중천창 작동여부','좌측일중천창 작동여부'],axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5255 entries, 0 to 5254
# Data columns (total 34 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   시설ID      5255 non-null   object
#  1   농가명       5255 non-null   object
#  2   시도        5255 non-null   object
#  3   시군구       5255 non-null   object
#  4   품목명       5255 non-null   object
#  5   품종        5255 non-null   object
#  6   재배면적      5255 non-null   int64
#  7   시설유형      5255 non-null   object
#  8   재배형태      5255 non-null   object
#  9   단동/연동 구분  5255 non-null   object
#  10  수집일       5255 non-null   object
#  11  외부온도      5168 non-null   float64
#  12  외부습도      5178 non-null   float64
#  13  외부풍향      5237 non-null   float64
#  14  외부풍속      4605 non-null   float64
#  15  강우감지      5237 non-null   float64
#  16  내부온도      5237 non-null   float64
#  17  내부습도      5099 non-null   float64
#  18  내부CO2     5248 non-null   float64
#  19  토양EC      3554 non-null   float64
# ...

# %%
df = df.drop(['외부온도','외부습도','외부풍향','외부풍속','강우감지'],axis=1)
df
# Out:
#                시설ID    농가명    시도  시군구 품목명    품종  재배면적 시설유형 재배형태 단동/연동 구분  \
# 0     PF_0001665_01  정****  경상북도  상주시  오이  백다다기  5200   비닐   수경       연동
# 1     PF_0001665_01  정****  경상북도  상주시  오이  백다다기  5200   비닐   수경       연동
# 2     PF_0001665_01  정****  경상북도  상주시  오이  백다다기  5200   비닐   수경       연동
# 3     PF_0001665_01  정****  경상북도  상주시  오이  백다다기  5200   비닐   수경       연동
# 4     PF_0001665_01  정****  경상북도  상주시  오이  백다다기  5200   비닐   수경       연동
# ...             ...    ...   ...  ...  ..   ...   ...  ...  ...      ...
# 5250  PF_0001665_01  정****  경상북도  상주시  오이  백다다기  5200   비닐   수경       연동
# 5251  PF_0001665_01  정****  경상북도  상주시  오이  백다다기  5200   비닐   수경       연동
# 5252  PF_0001665_01  정****  경상북도  상주시  오이  백다다기  5200   비닐   수경       연동
# 5253  PF_0001665_01  정****  경상북도  상주시  오이  백다다기  5200   비닐   수경       연동
# 5254  PF_0001665_01  정****  경상북도  상주시  오이  백다다기  5200   비닐   수경       연동
#
#                       수집일   내부온도  내부습도  내부CO2  토양EC  토양PH  (양액)배액PH  (양액)배액EC  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5255 entries, 0 to 5254
# Data columns (total 29 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   시설ID      5255 non-null   object
#  1   농가명       5255 non-null   object
#  2   시도        5255 non-null   object
#  3   시군구       5255 non-null   object
#  4   품목명       5255 non-null   object
#  5   품종        5255 non-null   object
#  6   재배면적      5255 non-null   int64
#  7   시설유형      5255 non-null   object
#  8   재배형태      5255 non-null   object
#  9   단동/연동 구분  5255 non-null   object
#  10  수집일       5255 non-null   object
#  11  내부온도      5237 non-null   float64
#  12  내부습도      5099 non-null   float64
#  13  내부CO2     5248 non-null   float64
#  14  토양EC      3554 non-null   float64
#  15  토양PH      3554 non-null   float64
#  16  (양액)배액PH  321 non-null    float64
#  17  (양액)배액EC  321 non-null    float64
#  18  조사일       410 non-null    object
#  19  주차        410 non-null    object
# ...

# %% [markdown]
# # 데이터 살피기

# %%
df['토양EC'][~ pd.isna(df['토양EC'])].unique()
# Out:
# array([0.])

# %%
df['토양PH'][~ pd.isna(df['토양PH'])].unique()
# Out:
# array([0.])

# %% [markdown]
# ## 양액 배액(ph),(양액)배액EC

# %%
df['(양액)배액PH'][~ pd.isna(df['(양액)배액PH'])].unique()
# Out:
# array([0.])

# %%
df['(양액)배액EC'][~ pd.isna(df['(양액)배액EC'])].unique()
# Out:
# array([0.])

# %% [markdown]
# ## 조사일

# %%
df['조사일'][~ pd.isna(df['조사일'])].unique()
# Out:
# array(['2021-02-01', '2021-02-08', '2021-02-14', '2021-02-22',
#        '2021-03-01', '2021-03-08', '2021-03-15', '2021-03-22',
#        '2021-03-29', '2021-04-05', '2021-04-12', '2021-04-19',
#        '2021-04-28', '2021-05-03', '2021-05-10', '2021-05-17',
#        '2021-05-24', '2021-05-31'], dtype=object)

# %%
len(df['조사일'][~ pd.isna(df['조사일'])].unique())
# Out:
# 18

# %% [markdown]
# ## 주차

# %%
df['주차'][~ pd.isna(df['주차'])].unique()
# Out:
# array(['5주차', '6주차', '7주차', '8주차', '9주차', '10주차', '11주차', '12주차', '13주차',
#        '14주차', '15주차', '16주차', '17주차', '18주차', '19주차', '20주차', '21주차',
#        '22주차'], dtype=object)

# %%
len(df['주차'][~ pd.isna(df['주차'])].unique())
# Out:
# 18

# %%
result_df = df[['조사일','주차','초장','마디수','엽장','엽폭','엽수','줄기직경','암꽃수','열매수','최종화방차수']]
result_df
# Out:
#       조사일   주차  초장  마디수  엽장  엽폭  엽수  줄기직경  암꽃수  열매수  최종화방차수
# 0     NaN  NaN NaN  NaN NaN NaN NaN   NaN  NaN  NaN     NaN
# 1     NaN  NaN NaN  NaN NaN NaN NaN   NaN  NaN  NaN     NaN
# 2     NaN  NaN NaN  NaN NaN NaN NaN   NaN  NaN  NaN     NaN
# 3     NaN  NaN NaN  NaN NaN NaN NaN   NaN  NaN  NaN     NaN
# 4     NaN  NaN NaN  NaN NaN NaN NaN   NaN  NaN  NaN     NaN
# ...   ...  ...  ..  ...  ..  ..  ..   ...  ...  ...     ...
# 5250  NaN  NaN NaN  NaN NaN NaN NaN   NaN  NaN  NaN     NaN
# 5251  NaN  NaN NaN  NaN NaN NaN NaN   NaN  NaN  NaN     NaN
# 5252  NaN  NaN NaN  NaN NaN NaN NaN   NaN  NaN  NaN     NaN
# 5253  NaN  NaN NaN  NaN NaN NaN NaN   NaN  NaN  NaN     NaN
# 5254  NaN  NaN NaN  NaN NaN NaN NaN   NaN  NaN  NaN     NaN
#
# [5255 rows x 11 columns]

# %%
result_df.corr()[abs(result_df.corr()) > 0.4]
# Out:
#               초장       마디수        엽장        엽폭        엽수      줄기직경       암꽃수  \
# 초장      1.000000 -0.413324 -0.552619  0.502345       NaN  0.766486       NaN
# 마디수    -0.413324  1.000000  0.931733  0.894672       NaN  0.989100  0.886134
# 엽장     -0.552619  0.931733  1.000000  0.887529       NaN       NaN  0.797720
# 엽폭      0.502345  0.894672  0.887529  1.000000 -0.473805  0.999910  0.842887
# 엽수           NaN       NaN       NaN -0.473805  1.000000 -0.598523 -0.513316
# 줄기직경    0.766486  0.989100       NaN  0.999910 -0.598523  1.000000  0.846436
# 암꽃수          NaN  0.886134  0.797720  0.842887 -0.513316  0.846436  1.000000
# 열매수          NaN  0.958041  0.974611  0.967524       NaN  0.906867  0.862959
# 최종화방차수       NaN       NaN       NaN -0.914807       NaN  1.000000       NaN
#
#              열매수    최종화방차수
# 초장           NaN       NaN
# 마디수     0.958041       NaN
# 엽장      0.974611       NaN
# 엽폭      0.967524 -0.914807
# 엽수           NaN       NaN
# 줄기직경    0.906867  1.000000
# ...

# %%
pd.notna(result_df).iloc[1830]
# Out:
# 조사일       True
# 주차        True
# 초장        True
# 마디수       True
# 엽장        True
# 엽폭        True
# 엽수        True
# 줄기직경      True
# 암꽃수       True
# 열매수       True
# 최종화방차수    True
# Name: 1830, dtype: bool

# %%
result_df.iloc[1830]
# Out:
# 조사일       2021-02-01
# 주차               5주차
# 초장              16.5
# 마디수             33.5
# 엽장              18.0
# 엽폭              24.5
# 엽수             17.25
# 줄기직경            6.75
# 암꽃수             3.75
# 열매수             7.75
# 최종화방차수           4.5
# Name: 1830, dtype: object

# %%
result_df[pd.notna(result_df)].iloc[1830]
# Out:
# 조사일       2021-02-01
# 주차               5주차
# 초장              16.5
# 마디수             33.5
# 엽장              18.0
# 엽폭              24.5
# 엽수             17.25
# 줄기직경            6.75
# 암꽃수             3.75
# 열매수             7.75
# 최종화방차수           4.5
# Name: 1830, dtype: object

# %%
remove_null_result = result_df[pd.notna(result_df['주차'])]
remove_null_result
# Out:
#              조사일    주차     초장    마디수     엽장     엽폭     엽수  줄기직경   암꽃수    열매수  \
# 1830  2021-02-01   5주차  16.50  33.50  18.00  24.50  17.25  6.75  3.75   7.75
# 1831  2021-02-01   5주차  16.50  33.50  18.00  24.50  17.25  6.75  3.75   7.75
# 1832  2021-02-01   5주차  16.50  33.50  18.00  24.50  17.25  6.75  3.75   7.75
# 1833  2021-02-01   5주차  16.50  33.50  18.00  24.50  17.25  6.75  3.75   7.75
# 1834  2021-02-01   5주차  16.50  33.50  18.00  24.50  17.25  6.75  3.75   7.75
# 1835  2021-02-01   5주차  16.50  33.50  18.00  24.50  17.25  6.75  3.75   7.75
# 1836  2021-02-01   5주차  16.50  33.50  18.00  24.50  17.25  6.75  3.75   7.75
# 1837  2021-02-01   5주차  16.50  33.50  18.00  24.50  17.25  6.75  3.75   7.75
# 1838  2021-02-01   5주차  16.50  33.50  18.00  24.50  17.25  6.75  3.75   7.75
# 1839  2021-02-01   5주차  16.50  33.50  18.00  24.50  17.25  6.75  3.75   7.75
# 1840  2021-02-01   5주차  16.50  33.50  18.00  24.50  17.25  6.75  3.75   7.75
# ...

# %%
remove_null_result[['조사일','주차','열매수','최종화방차수']]
# Out:
#              조사일    주차    열매수  최종화방차수
# 1830  2021-02-01   5주차   7.75    4.50
# 1831  2021-02-01   5주차   7.75    4.50
# 1832  2021-02-01   5주차   7.75    4.50
# 1833  2021-02-01   5주차   7.75    4.50
# 1834  2021-02-01   5주차   7.75    4.50
# 1835  2021-02-01   5주차   7.75    4.50
# 1836  2021-02-01   5주차   7.75    4.50
# 1837  2021-02-01   5주차   7.75    4.50
# 1838  2021-02-01   5주차   7.75    4.50
# 1839  2021-02-01   5주차   7.75    4.50
# 1840  2021-02-01   5주차   7.75    4.50
# 1841  2021-02-01   5주차   7.75    4.50
# 1842  2021-02-01   5주차   7.75    4.50
# 1843  2021-02-01   5주차   7.75    4.50
# 1844  2021-02-01   5주차   7.75    4.50
# 1845  2021-02-01   5주차   7.75    4.50
# 1846  2021-02-01   5주차   7.75    4.50
# 1847  2021-02-01   5주차   7.75    4.50
# 1848  2021-02-01   5주차   7.75    4.50
# 1849  2021-02-01   5주차   7.75    4.50
# 1850  2021-02-01   5주차   7.75    4.50
# 1851  2021-02-01   5주차   7.75    4.50
# 1852  2021-02-01   5주차   7.75    4.50
# 1853  2021-02-01   5주차   7.75    4.50
# ...

# %%
remove_null_result.plot(y='열매수',x='주차_int',grid=True,yticks=y_range,xticks=x_range,kind = 'scatter')
# Out:
# <AxesSubplot:xlabel='주차_int', ylabel='열매수'>

# %%
remove_null_result.plot(y='열매수',x='주차_int',grid=True,yticks=y_range,xticks=x_range,kind = 'line')
# Out:
# <AxesSubplot:xlabel='주차_int'>

# %% [markdown]
# # 데이터가 너무 없기 때문에 다른 오이 값을 참고해보자

# %% [markdown]
# # df_1

# %%
df_1 = pd.read_excel(path + '경기도_이--농가데이터셋_오이.xlsx')

# %%
df_1[['시설유형','재배형태']]
# Out:
#      시설유형 재배형태
# 0      비닐   토경
# 1      비닐   토경
# 2      비닐   토경
# 3      비닐   토경
# 4      비닐   토경
# ...   ...  ...
# 2704   비닐   토경
# 2705   비닐   토경
# 2706   비닐   토경
# 2707   비닐   토경
# 2708   비닐   토경
#
# [2709 rows x 2 columns]

# %%
result_df_1 = df_1[['조사일','주차','초장','마디수','엽장','엽폭','엽수','줄기직경','암꽃수','열매수','최종화방차수']]
result_df_1
# Out:
#       조사일   주차  초장  마디수  엽장  엽폭  엽수  줄기직경  암꽃수  열매수  최종화방차수
# 0     NaN  NaN NaN  NaN NaN NaN NaN   NaN  NaN  NaN     NaN
# 1     NaN  NaN NaN  NaN NaN NaN NaN   NaN  NaN  NaN     NaN
# 2     NaN  NaN NaN  NaN NaN NaN NaN   NaN  NaN  NaN     NaN
# 3     NaN  NaN NaN  NaN NaN NaN NaN   NaN  NaN  NaN     NaN
# 4     NaN  NaN NaN  NaN NaN NaN NaN   NaN  NaN  NaN     NaN
# ...   ...  ...  ..  ...  ..  ..  ..   ...  ...  ...     ...
# 2704  NaN  NaN NaN  NaN NaN NaN NaN   NaN  NaN  NaN     NaN
# 2705  NaN  NaN NaN  NaN NaN NaN NaN   NaN  NaN  NaN     NaN
# 2706  NaN  NaN NaN  NaN NaN NaN NaN   NaN  NaN  NaN     NaN
# 2707  NaN  NaN NaN  NaN NaN NaN NaN   NaN  NaN  NaN     NaN
# 2708  NaN  NaN NaN  NaN NaN NaN NaN   NaN  NaN  NaN     NaN
#
# [2709 rows x 11 columns]

# %%
remove_null_result_1 = result_df_1[pd.notna(result_df_1['주차'])]
remove_null_result_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 477 entries, 90 to 2558
# Data columns (total 11 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   조사일     477 non-null    object
#  1   주차      477 non-null    object
#  2   초장      477 non-null    float64
#  3   마디수     477 non-null    float64
#  4   엽장      431 non-null    float64
#  5   엽폭      454 non-null    float64
#  6   엽수      458 non-null    float64
#  7   줄기직경    454 non-null    float64
#  8   암꽃수     215 non-null    float64
#  9   열매수     263 non-null    float64
#  10  최종화방차수  477 non-null    float64
# dtypes: float64(9), object(2)
# memory usage: 44.7+ KB

# %%
remove_null_result.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 410 entries, 1830 to 4607
# Data columns (total 11 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   조사일     410 non-null    object
#  1   주차      410 non-null    object
#  2   초장      362 non-null    float64
#  3   마디수     410 non-null    float64
#  4   엽장      266 non-null    float64
#  5   엽폭      192 non-null    float64
#  6   엽수      266 non-null    float64
#  7   줄기직경    120 non-null    float64
#  8   암꽃수     314 non-null    float64
#  9   열매수     216 non-null    float64
#  10  최종화방차수  144 non-null    float64
# dtypes: float64(9), object(2)
# memory usage: 38.4+ KB

# %%
remove_null_result_1['주차'].unique()
# Out:
# array(['16주차', '17주차', '18주차', '19주차', '20주차', '21주차', '22주차', '23주차',
#        '24주차', '25주차', '26주차', '27주차', '28주차', '29주차', '30주차', '31주차',
#        '32주차', '33주차'], dtype=object)

# %%
remove_null_result['주차'].unique()
# Out:
# array(['5주차', '6주차', '7주차', '8주차', '9주차', '10주차', '11주차', '12주차', '13주차',
#        '14주차', '15주차', '16주차', '17주차', '18주차', '19주차', '20주차', '21주차',
#        '22주차'], dtype=object)

# %%
len(remove_null_result_1['주차'].unique())
# Out:
# 18

# %%
len(remove_null_result['주차'].unique())
# Out:
# 18

# %% [markdown]
# # 그래프

# %% [markdown]
# ## scatter

# %%
x_range = range(5,40)
y_range = range(0,13)

# %%
remove_null_result_1.plot(y='열매수',x='주차_int',grid=True,yticks=y_range,xticks=x_range,kind = 'scatter')
# Out:
# <AxesSubplot:xlabel='주차_int', ylabel='열매수'>

# %%
remove_null_result.plot(y='열매수',x='주차_int',grid=True,yticks=y_range,xticks=x_range,kind = 'scatter')
# Out:
# <AxesSubplot:xlabel='주차_int', ylabel='열매수'>

# %% [markdown]
# ## line

# %%
remove_null_result_1.plot(y='열매수',x='주차_int',grid=True,yticks=y_range,xticks=x_range,kind = 'line')
# Out:
# <AxesSubplot:xlabel='주차_int'>

# %%
remove_null_result.plot(y='열매수',x='주차_int',grid=True,yticks=y_range,xticks=x_range,kind = 'line')
# Out:
# <AxesSubplot:xlabel='주차_int'>

# %%
remove_null_result_1[['조사일']].iloc[0]
# Out:
# 조사일    2021-02-10
# Name: 90, dtype: object

# %%
remove_null_result[['조사일']].iloc[0]
# Out:
# 조사일    2021-02-01
# Name: 1830, dtype: object

# %%
remove_null_result[['조사일']].iloc[409]
# Out:
# 조사일    2021-05-31
# Name: 4607, dtype: object

# %%
remove_null_result_1[['조사일']].iloc[476]
# Out:
# 조사일    2021-06-08
# Name: 2558, dtype: object

# %% [markdown]
# # df_2

# %%
df_2 = pd.read_excel(path + '경상북도_이--농가데이터셋_오이.xlsx')

# %%
df_2[['시설유형','재배형태']]
# Out:
#      시설유형 재배형태
# 0      비닐   토경
# 1      비닐   토경
# 2      비닐   토경
# 3      비닐   토경
# 4      비닐   토경
# ...   ...  ...
# 5632   비닐   토경
# 5633   비닐   토경
# 5634   비닐   토경
# 5635   비닐   토경
# 5636   비닐   토경
#
# [5637 rows x 2 columns]

# %%
result_df_2 = df_2[['조사일','주차','초장','마디수','엽장','엽폭','엽수','줄기직경','암꽃수','열매수','최종화방차수']]
result_df_2
# Out:
#       조사일   주차  초장  마디수  엽장  엽폭  엽수  줄기직경  암꽃수  열매수  최종화방차수
# 0     NaN  NaN NaN  NaN NaN NaN NaN   NaN  NaN  NaN     NaN
# 1     NaN  NaN NaN  NaN NaN NaN NaN   NaN  NaN  NaN     NaN
# 2     NaN  NaN NaN  NaN NaN NaN NaN   NaN  NaN  NaN     NaN
# 3     NaN  NaN NaN  NaN NaN NaN NaN   NaN  NaN  NaN     NaN
# 4     NaN  NaN NaN  NaN NaN NaN NaN   NaN  NaN  NaN     NaN
# ...   ...  ...  ..  ...  ..  ..  ..   ...  ...  ...     ...
# 5632  NaN  NaN NaN  NaN NaN NaN NaN   NaN  NaN  NaN     NaN
# 5633  NaN  NaN NaN  NaN NaN NaN NaN   NaN  NaN  NaN     NaN
# 5634  NaN  NaN NaN  NaN NaN NaN NaN   NaN  NaN  NaN     NaN
# 5635  NaN  NaN NaN  NaN NaN NaN NaN   NaN  NaN  NaN     NaN
# 5636  NaN  NaN NaN  NaN NaN NaN NaN   NaN  NaN  NaN     NaN
#
# [5637 rows x 11 columns]

# %%
remove_null_result_2 = result_df_2[pd.notna(result_df_2['주차'])]
remove_null_result_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 443 entries, 2213 to 5452
# Data columns (total 11 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   조사일     443 non-null    object
#  1   주차      443 non-null    object
#  2   초장      435 non-null    float64
#  3   마디수     443 non-null    float64
#  4   엽장      347 non-null    float64
#  5   엽폭      442 non-null    float64
#  6   엽수      265 non-null    float64
#  7   줄기직경    370 non-null    float64
#  8   암꽃수     168 non-null    float64
#  9   열매수     298 non-null    float64
#  10  최종화방차수  443 non-null    float64
# dtypes: float64(9), object(2)
# memory usage: 41.5+ KB

# %%
remove_null_result.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 410 entries, 1830 to 4607
# Data columns (total 11 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   조사일     410 non-null    object
#  1   주차      410 non-null    object
#  2   초장      362 non-null    float64
#  3   마디수     410 non-null    float64
#  4   엽장      266 non-null    float64
#  5   엽폭      192 non-null    float64
#  6   엽수      266 non-null    float64
#  7   줄기직경    120 non-null    float64
#  8   암꽃수     314 non-null    float64
#  9   열매수     216 non-null    float64
#  10  최종화방차수  144 non-null    float64
# dtypes: float64(9), object(2)
# memory usage: 38.4+ KB

# %%
remove_null_result_2['주차'].unique()
# Out:
# array(['19주차', '20주차', '21주차', '22주차', '23주차', '24주차', '25주차', '26주차',
#        '27주차', '28주차', '29주차', '30주차', '31주차', '32주차', '33주차', '34주차',
#        '35주차', '36주차', '37주차', '38주차', '39주차'], dtype=object)

# %%
remove_null_result['주차'].unique()
# Out:
# array(['5주차', '6주차', '7주차', '8주차', '9주차', '10주차', '11주차', '12주차', '13주차',
#        '14주차', '15주차', '16주차', '17주차', '18주차', '19주차', '20주차', '21주차',
#        '22주차'], dtype=object)

# %%
len(remove_null_result_2['주차'].unique())
# Out:
# 21

# %%
len(remove_null_result['주차'].unique())
# Out:
# 18

# %%
remove_null_result_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 443 entries, 2213 to 5452
# Data columns (total 11 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   조사일     443 non-null    object
#  1   주차      443 non-null    object
#  2   초장      435 non-null    float64
#  3   마디수     443 non-null    float64
#  4   엽장      347 non-null    float64
#  5   엽폭      442 non-null    float64
#  6   엽수      265 non-null    float64
#  7   줄기직경    370 non-null    float64
#  8   암꽃수     168 non-null    float64
#  9   열매수     298 non-null    float64
#  10  최종화방차수  443 non-null    float64
# dtypes: float64(9), object(2)
# memory usage: 41.5+ KB

# %%
remove_null_result_2['주차'].unique()
# Out:
# array(['19주차', '20주차', '21주차', '22주차', '23주차', '24주차', '25주차', '26주차',
#        '27주차', '28주차', '29주차', '30주차', '31주차', '32주차', '33주차', '34주차',
#        '35주차', '36주차', '37주차', '38주차', '39주차'], dtype=object)

# %%
remove_null_result_1['주차'].unique()
# Out:
# array(['16주차', '17주차', '18주차', '19주차', '20주차', '21주차', '22주차', '23주차',
#        '24주차', '25주차', '26주차', '27주차', '28주차', '29주차', '30주차', '31주차',
#        '32주차', '33주차'], dtype=object)

# %%
remove_null_result['주차'].unique()
# Out:
# array(['5주차', '6주차', '7주차', '8주차', '9주차', '10주차', '11주차', '12주차', '13주차',
#        '14주차', '15주차', '16주차', '17주차', '18주차', '19주차', '20주차', '21주차',
#        '22주차'], dtype=object)

# %%
remove_null_result['주차_int'] = remove_null_result['주차'].apply(lambda x:int(x[:-2]))
remove_null_result
# Out:
# C:\Users\minjumg\AppData\Local\Temp/ipykernel_14560/1158264614.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   remove_null_result['주차_int'] = remove_null_result['주차'].apply(lambda x:int(x[:-2]))
#              조사일    주차     초장    마디수     엽장     엽폭     엽수  줄기직경   암꽃수    열매수  \
# 1830  2021-02-01   5주차  16.50  33.50  18.00  24.50  17.25  6.75  3.75   7.75
# 1831  2021-02-01   5주차  16.50  33.50  18.00  24.50  17.25  6.75  3.75   7.75
# 1832  2021-02-01   5주차  16.50  33.50  18.00  24.50  17.25  6.75  3.75   7.75
# 1833  2021-02-01   5주차  16.50  33.50  18.00  24.50  17.25  6.75  3.75   7.75
# 1834  2021-02-01   5주차  16.50  33.50  18.00  24.50  17.25  6.75  3.75   7.75
# ...

# %%
remove_null_result_1['주차_int'] = remove_null_result_1['주차'].apply(lambda x:int(x[:-2]))
remove_null_result_1
# Out:
# C:\Users\minjumg\AppData\Local\Temp/ipykernel_14560/4159454896.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   remove_null_result_1['주차_int'] = remove_null_result_1['주차'].apply(lambda x:int(x[:-2]))
#              조사일    주차      초장    마디수     엽장     엽폭     엽수  줄기직경   암꽃수   열매수  \
# 90    2021-02-10  16주차  373.50  39.75  17.15  26.55  28.75  8.03  1.00  9.00
# 91    2021-02-10  16주차  373.50  39.75  17.15  26.55  28.75  8.03  1.00  9.00
# 92    2021-02-10  16주차  373.50  39.75  17.15  26.55  28.75  8.03  1.00  9.00
# 93    2021-02-10  16주차  373.50  39.75  17.15  26.55  28.75  8.03  1.00  9.00
# 94    2021-02-10  16주차  373.50  39.75  17.15  26.55  28.75  8.03  1.00  9.00
# ...

# %%
remove_null_result_2['주차_int'] = remove_null_result_2['주차'].apply(lambda x:int(x[:-2]))
remove_null_result_2
# Out:
# C:\Users\minjumg\AppData\Local\Temp/ipykernel_14560/3390461228.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   remove_null_result_2['주차_int'] = remove_null_result_2['주차'].apply(lambda x:int(x[:-2]))
#              조사일    주차     초장    마디수     엽장     엽폭     엽수  줄기직경   암꽃수   열매수  \
# 2213  2021-02-01  19주차  28.68  55.00  17.65  25.08  13.00  7.75  0.75  5.00
# 2214  2021-02-01  19주차  28.68  55.00  17.65  25.08  13.00  7.75  0.75  5.00
# 2215  2021-02-01  19주차  28.68  55.00  17.65  25.08  13.00  7.75  0.75  5.00
# 2216  2021-02-01  19주차  28.68  55.00  17.65  25.08  13.00  7.75  0.75  5.00
# 2217  2021-02-01  19주차  28.68  55.00  17.65  25.08  13.00  7.75  0.75  5.00
# ...

# %% [markdown]
# # 그래프

# %% [markdown]
# ## scatter

# %%
remove_null_result_2.plot(y='열매수',x='주차_int',grid=True,yticks=y_range,xticks=x_range, kind='scatter')
# Out:
# <AxesSubplot:xlabel='주차_int', ylabel='열매수'>

# %%
remove_null_result_1.plot(y='열매수',x='주차_int', grid=True, yticks=y_range, xticks=x_range, kind='scatter')
# Out:
# <AxesSubplot:xlabel='주차_int', ylabel='열매수'>

# %%
remove_null_result.plot(y='열매수',x='주차_int',grid=True, yticks=y_range, xticks=x_range, kind='scatter')
# Out:
# <AxesSubplot:xlabel='주차_int', ylabel='열매수'>

# %% [markdown]
# ## line

# %%
x_range = [0,5,10,15,20,25,30,35,40]

# %%
remove_null_result_2.plot(y='열매수',x='주차_int',grid=True,yticks=y_range,xticks=x_range)
# Out:
# <AxesSubplot:xlabel='주차_int'>

# %%
remove_null_result_1.plot(y='열매수',x='주차_int', grid=True, yticks=y_range, xticks=x_range)
# Out:
# <AxesSubplot:xlabel='주차_int'>

# %%
remove_null_result.plot(y='열매수',x='주차_int',grid=True, yticks=y_range, xticks=x_range)
# Out:
# <AxesSubplot:xlabel='주차_int'>

# %% [markdown]
# # df_3

# %%
df_3 = pd.read_excel(path + '충청남도_김--(2)농가데이터셋_오이.xls')

# %%
df_3[['시설유형','재배형태']]
# Out:
#       시설유형  재배형태
# 0      NaN   NaN
# 1      NaN   NaN
# 2      NaN   NaN
# 3      NaN   NaN
# 4      NaN   NaN
# ...    ...   ...
# 2384   NaN   NaN
# 2385   NaN   NaN
# 2386   NaN   NaN
# 2387   NaN   NaN
# 2388   NaN   NaN
#
# [2389 rows x 2 columns]

# %%
result_df_3 = df_3[['조사일','주차','초장','마디수','엽장','엽폭','엽수','줄기직경','암꽃수','열매수','최종화방차수']]
result_df_3
# Out:
#              조사일    주차     초장   마디수     엽장    엽폭    엽수  줄기직경  암꽃수  열매수  최종화방차수
# 0     2021-02-04  10주차  144.0  16.5  19.25  27.0  10.0  7.01  1.0  4.0    5.75
# 1     2021-02-04  10주차  144.0  16.5  19.25  27.0  10.0  7.01  1.0  4.0    5.75
# 2     2021-02-04  10주차  144.0  16.5  19.25  27.0  10.0  7.01  1.0  4.0    5.75
# 3     2021-02-04  10주차  144.0  16.5  19.25  27.0  10.0  7.01  1.0  4.0    5.75
# 4     2021-02-04  10주차  144.0  16.5  19.25  27.0  10.0  7.01  1.0  4.0    5.75
# ...          ...   ...    ...   ...    ...   ...   ...   ...  ...  ...     ...
# 2384         NaN   NaN    NaN   NaN    NaN   NaN   NaN   NaN  NaN  NaN     NaN
# 2385         NaN   NaN    NaN   NaN    NaN   NaN   NaN   NaN  NaN  NaN     NaN
# 2386         NaN   NaN    NaN   NaN    NaN   NaN   NaN   NaN  NaN  NaN     NaN
# 2387         NaN   NaN    NaN   NaN    NaN   NaN   NaN   NaN  NaN  NaN     NaN
# 2388         NaN   NaN    NaN   NaN    NaN   NaN   NaN   NaN  NaN  NaN     NaN
#
# ...

# %%
remove_null_result_3 = result_df_3[pd.notna(result_df_3['주차'])]
remove_null_result_3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 349 entries, 0 to 2365
# Data columns (total 11 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   조사일     349 non-null    object
#  1   주차      349 non-null    object
#  2   초장      349 non-null    float64
#  3   마디수     349 non-null    float64
#  4   엽장      349 non-null    float64
#  5   엽폭      349 non-null    float64
#  6   엽수      349 non-null    float64
#  7   줄기직경    349 non-null    float64
#  8   암꽃수     349 non-null    float64
#  9   열매수     349 non-null    float64
#  10  최종화방차수  349 non-null    float64
# dtypes: float64(9), object(2)
# memory usage: 32.7+ KB

# %%
remove_null_result.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 410 entries, 1830 to 4607
# Data columns (total 12 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   조사일     410 non-null    object
#  1   주차      410 non-null    object
#  2   초장      362 non-null    float64
#  3   마디수     410 non-null    float64
#  4   엽장      266 non-null    float64
#  5   엽폭      192 non-null    float64
#  6   엽수      266 non-null    float64
#  7   줄기직경    120 non-null    float64
#  8   암꽃수     314 non-null    float64
#  9   열매수     216 non-null    float64
#  10  최종화방차수  144 non-null    float64
#  11  주차_int  410 non-null    int64
# dtypes: float64(9), int64(1), object(2)
# memory usage: 41.6+ KB

# %%
remove_null_result_3 = result_df_3[pd.notna(result_df_3['주차'])]
remove_null_result_3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 349 entries, 0 to 2365
# Data columns (total 11 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   조사일     349 non-null    object
#  1   주차      349 non-null    object
#  2   초장      349 non-null    float64
#  3   마디수     349 non-null    float64
#  4   엽장      349 non-null    float64
#  5   엽폭      349 non-null    float64
#  6   엽수      349 non-null    float64
#  7   줄기직경    349 non-null    float64
#  8   암꽃수     349 non-null    float64
#  9   열매수     349 non-null    float64
#  10  최종화방차수  349 non-null    float64
# dtypes: float64(9), object(2)
# memory usage: 32.7+ KB

# %%
remove_null_result_3['주차'].unique()
# Out:
# array(['10주차', '11주차', '12주차', '13주차', '14주차', '15주차', '16주차', '17주차',
#        '18주차', '19주차', '20주차', '21주차', '22주차', '23주차', '24주차', '25주차'],
#       dtype=object)

# %%
remove_null_result_3
# Out:
#              조사일    주차      초장    마디수     엽장     엽폭     엽수  줄기직경   암꽃수   열매수  \
# 0     2021-02-04  10주차  144.00  16.50  19.25  27.00  10.00  7.01  1.00  4.00
# 1     2021-02-04  10주차  144.00  16.50  19.25  27.00  10.00  7.01  1.00  4.00
# 2     2021-02-04  10주차  144.00  16.50  19.25  27.00  10.00  7.01  1.00  4.00
# 3     2021-02-04  10주차  144.00  16.50  19.25  27.00  10.00  7.01  1.00  4.00
# 4     2021-02-04  10주차  144.00  16.50  19.25  27.00  10.00  7.01  1.00  4.00
# 5     2021-02-04  10주차  144.00  16.50  19.25  27.00  10.00  7.01  1.00  4.00
# 6     2021-02-04  10주차  144.00  16.50  19.25  27.00  10.00  7.01  1.00  4.00
# 7     2021-02-04  10주차  144.00  16.50  19.25  27.00  10.00  7.01  1.00  4.00
# 8     2021-02-04  10주차  144.00  16.50  19.25  27.00  10.00  7.01  1.00  4.00
# 9     2021-02-04  10주차  144.00  16.50  19.25  27.00  10.00  7.01  1.00  4.00
# 10    2021-02-04  10주차  144.00  16.50  19.25  27.00  10.00  7.01  1.00  4.00
# ...

# %%
remove_null_result_3['주차_int'] = remove_null_result_3['주차'].apply(lambda x:int(x[:-2]))
remove_null_result_3
# Out:
# C:\Users\minjumg\AppData\Local\Temp/ipykernel_14560/3852241199.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   remove_null_result_3['주차_int'] = remove_null_result_3['주차'].apply(lambda x:int(x[:-2]))
#              조사일    주차      초장    마디수     엽장     엽폭     엽수  줄기직경   암꽃수   열매수  \
# 0     2021-02-04  10주차  144.00  16.50  19.25  27.00  10.00  7.01  1.00  4.00
# 1     2021-02-04  10주차  144.00  16.50  19.25  27.00  10.00  7.01  1.00  4.00
# 2     2021-02-04  10주차  144.00  16.50  19.25  27.00  10.00  7.01  1.00  4.00
# 3     2021-02-04  10주차  144.00  16.50  19.25  27.00  10.00  7.01  1.00  4.00
# 4     2021-02-04  10주차  144.00  16.50  19.25  27.00  10.00  7.01  1.00  4.00
# ...

# %%
remove_null_result_3.columns
# Out:
# Index(['조사일', '주차', '초장', '마디수', '엽장', '엽폭', '엽수', '줄기직경', '암꽃수', '열매수',
#        '최종화방차수', '주차_int'],
#       dtype='object')

# %%
x_range = range(5,40)
y_range = range(0,13)

# %% [markdown]
# # 그래프

# %% [markdown]
# ## scatter

# %%
remove_null_result_3.plot(y='열매수',x='주차_int',grid=True,yticks=y_range,xticks=x_range,kind = 'scatter')
# Out:
# <AxesSubplot:xlabel='주차_int', ylabel='열매수'>

# %%
remove_null_result_2.plot(y='열매수',x='주차_int',grid=True,yticks=y_range,xticks=x_range,kind = 'scatter')
# Out:
# <AxesSubplot:xlabel='주차_int', ylabel='열매수'>

# %%
remove_null_result_1.plot(y='열매수',x='주차_int',grid=True, yticks=y_range, xticks = x_range, kind = 'scatter')
# Out:
# <AxesSubplot:xlabel='주차_int', ylabel='열매수'>

# %%
remove_null_result.plot(y='열매수',x='주차_int',grid=True,yticks=y_range,xticks=x_range,kind = 'scatter')
# Out:
# <AxesSubplot:xlabel='주차_int', ylabel='열매수'>

# %% [markdown]
# ## line

# %%
remove_null_result_3.plot(y='열매수',x='주차_int',grid=True,yticks=y_range,xticks=x_range,kind = 'line')
# Out:
# <AxesSubplot:xlabel='주차_int'>

# %%
remove_null_result_2.plot(y='열매수',x='주차_int',grid=True,yticks=y_range,xticks=x_range,kind = 'line')
# Out:
# <AxesSubplot:xlabel='주차_int'>

# %%
remove_null_result_1.plot(y='열매수',x='주차_int',grid=True, yticks=y_range, xticks = x_range, kind = 'line')
# Out:
# <AxesSubplot:xlabel='주차_int'>

# %%
remove_null_result.plot(y='열매수',x='주차_int',grid=True,yticks=y_range,xticks=x_range,kind = 'line')
# Out:
# <AxesSubplot:xlabel='주차_int'>
